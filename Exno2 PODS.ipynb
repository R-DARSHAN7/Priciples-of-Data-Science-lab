# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Titanic-Dataset.csv')
df=pd.DataFrame(data)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
#this returns  the mathematical description of the data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Cabin'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Cabin']=df['Cabin'].fillna('Unknown')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'][0])

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
sns.countplot(x='Pclass', data=df)
plt.show()

# %%
df[(df['Sex']=='female')&(df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Pclass']==3)&(df['Age']<=18)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 855          856         1       3               Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[(df['Pclass']==1)&(df['Age']>=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Pclass']==1)&(df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex']=='male')&(df['Fare']>100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 118          119         0       1
# 305          306         1       1
# 332          333         0       1
# 373          374         0       1
# 377          378         0       1
# 390          391         1       1
# 438          439         0       1
# 505          506         0       1
# 527          528         0       1
# 544          545         0       1
# 550          551         1       1
# 557          558         0       1
# 659          660         0       1
# 660          661         1       1
# 679          680         1       1
# 698          699         0       1
# 737          738         1       1
# 802          803         1       1
#
#                                            Name   Sex    Age  SibSp  Parch  \
# 27               Fortune, Mr. Charles Alexander  male  19.00      3      2
# 118                    Baxter, Mr. Quigg Edmond  male  24.00      0      1
# ...

# %%
df[(df['Embarked']=='C')&(df['Pclass']==2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 43            44         1       2
# 122          123         0       2
# 135          136         0       2
# 181          182         0       2
# 292          293         0       2
# 308          309         0       2
# 361          362         0       2
# 389          390         1       2
# 473          474         1       2
# 547          548         1       2
# 608          609         1       2
# 685          686         0       2
# 817          818         0       2
# 827          828         1       2
# 866          867         1       2
# 874          875         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 122                               Nasser, Mr. Nicholas    male  32.5      1
# ...

# %%
df[(df['SibSp']>2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 24            25         0       3
# 27            28         0       1
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 85            86         1       3
# 88            89         1       1
# 119          120         0       3
# 159          160         0       3
# 164          165         0       3
# 171          172         0       3
# 176          177         0       3
# 180          181         0       3
# 182          183         0       3
# 201          202         0       3
# 229          230         0       3
# 233          234         1       3
# 261          262         1       3
# 266          267         0       3
# 278          279         0       3
# 324          325         0       3
# ...

# %%
df[((df['SibSp']==0) &(df['Parch']==0))&(df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 5              6         0       3                      Moran, Mr. James
# 6              7         0       1               McCarthy, Mr. Timothy J
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# ...

# %%
df['Age'].dropna()
sort_age=df['Age'].sort_values(ascending=False)
sort_age.head()
# Out:
# 630    80.0
# 851    74.0
# 493    71.0
# 96     71.0
# 116    70.5
# Name: Age, dtype: float64

# %%
min=70.5
df[(df['Survived']==0)&(df['Age']>=70.5)]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 96            97         0       1  Goldschmidt, Mr. George B  male  71.0
# 116          117         0       3       Connors, Mr. Patrick  male  70.5
# 493          494         0       1    Artagaveytia, Mr. Ramon  male  71.0
# 851          852         0       3        Svensson, Mr. Johan  male  74.0
#
#      SibSp  Parch    Ticket     Fare    Cabin Embarked
# 96       0      0  PC 17754  34.6542       A5        C
# 116      0      0    370369   7.7500  Unknown        Q
# 493      0      0  PC 17609  49.5042  Unknown        C
# 851      0      0    347060   7.7750  Unknown        S

# %%
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
from sklearn.model_selection import train_test_split
x_train=df.drop('Survived',axis=1)
y_train=df['Survived']
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.2)

# %%
x_train
# Out:
#      PassengerId  Pclass                                        Name     Sex  \
# 715          716       3  Soholt, Mr. Peter Andreas Lauritz Andersen    male
# 266          267       3                   Panula, Mr. Ernesti Arvid    male
# 123          124       2                         Webber, Miss. Susan  female
# 729          730       3               Ilmakangas, Miss. Pieta Sofia  female
# 281          282       3            Olsson, Mr. Nils Johan Goransson    male
# ..           ...     ...                                         ...     ...
# 398          399       2                            Pain, Dr. Alfred    male
# 783          784       3                      Johnston, Mr. Andrew G    male
# 872          873       1                    Carlsson, Mr. Frans Olof    male
# 652          653       3              Kalvik, Mr. Johannes Halvorsen    male
# 177          178       1                  Isham, Miss. Ann Elizabeth  female
#
# ...

# %%
y_train
# Out:
# 715    0
# 266    0
# 123    1
# 729    0
# 281    0
#       ..
# 398    0
# 783    0
# 872    0
# 652    0
# 177    0
# Name: Survived, Length: 712, dtype: int64
